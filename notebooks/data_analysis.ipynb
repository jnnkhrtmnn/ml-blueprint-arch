# %% [markdown]
# # Data Analysis notebook for highly sophisticated analysis

# %%
# dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## Data import

# %%
# load data
path = Path('C:/Users/janni/Desktop/blueprint/ml-blueprint-arch')
df = pd.read_pickle(path / 'data' / 'dat.pkl')

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#                  y           x1           x2
# count  1000.000000  1000.000000  1000.000000
# mean     29.917042     9.788264    20.069039
# std       7.180380     5.080980     5.034226
# min       5.517350    -9.801584     1.742554
# 25%      25.158477     6.373496    16.836043
# 50%      30.030833     9.933175    20.116441
# 75%      35.028880    13.167167    23.459607
# max      49.018936    24.894449    33.877071

# %%
df['y'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Oh wow, what a surprise, it appears normally distributed. Who could have guessed?

# %%
df['x1'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Same here?!

# %%
df['x2'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# And same here, too?!

# %% [markdown]
# Let's check if our variables are actually correlated.

# %%
df.corr()
# Out:
#            y        x1        x2
# y   1.000000  0.706198  0.690313
# x1  0.706198  1.000000 -0.006201
# x2  0.690313 -0.006201  1.000000

# %% [markdown]
# Oh wow, they are! This analysis is spot-on!

# %%
df.plot.scatter(x='x1', y='x2')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
df.plot.scatter(x='x1', y='y')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='y'>

# %%
df.plot.scatter(x='x2', y='y')
# Out:
# <AxesSubplot:xlabel='x2', ylabel='y'>

# %% [markdown]
# #### Obvious linear correlations, no (linear) correlation between our dependent variables. Let's go for a linear regression model, then?
